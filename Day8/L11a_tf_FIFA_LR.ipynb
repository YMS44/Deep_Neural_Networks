# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

# %% [markdown]
# # Deep Neural Networks
# ## Session 011
#
# ## Working with Tensorflow
# - One hidden layer
# - ${Swish}$ activation function
# - Adam
# - Multi-class output
# - FIFA dataset
#
# <img src='../../prasami_images/prasami_color_tutorials_small.png' width='400' alt="By Pramod Sharma : pramod.sharma@prasami.com" align="left"/>

# %%
###-----------------
### Import Libraries
###-----------------

import os
import sys
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
from time import time
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, ConfusionMatrixDisplay
from sklearn.preprocessing import StandardScaler

import tensorflow as tf

# from utils.helper import fn_plot_tf_hist, fn_plot_confusion_matrix

# %%
###----------------------
### Some basic parameters
###----------------------

inpDir = '../../input' # location where input data is stored
outDir = '../output' # location to store outputs
modelDir = '../models' # location of the images
subDir = 'fifa_2019'
logDir = '../logs'

RANDOM_STATE = 24 # for initialization ----- REMEMBER: to remove at the time of promotion to production
np.random.seed(RANDOM_STATE) # Set Random Seed for reproducible  results
tf.random.set_seed(RANDOM_STATE) # setting for Tensorflow as well


EPOCHS = 101 # number of epochs
ALPHA = 0.001 # learning rate

BATCH_SIZE = 32
REG_Lambda = 0.001
TEST_SIZE = 0.2

PATIENCE = 20
LR_PATIENCE = 10
LR_FACTOR = 0.1

# Set parameters for decoration of plots
params = {'legend.fontsize' : 'medium',
          'figure.figsize'  : (15,6),
          'axes.labelsize'  : 'large',
          'axes.titlesize'  :'large',
          'xtick.labelsize' :'medium',
          'ytick.labelsize' :'medium',
         }

CMAP = plt.cm.coolwarm

plt.rcParams.update(params) # update rcParams

plt.style.use('seaborn-v0_8-darkgrid') # plt.style.use('ggplot')

# %%
###----------------------
### Plot confusion matrix
###----------------------
def fn_plot_confusion_matrix(y_true, y_pred, labels):
    '''
    Args:
        y_true: Ground Truth 
        y_pred : Predictions
        labels : dictonary 
                  {0: 'Goal Keeper', 
                  1: 'Defender', 
                  2: 'Mid-Fielder', 
                  3: 'Forward'}
    
    '''
    
    cm  = confusion_matrix(y_true, y_pred)
    
    disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                                  display_labels=labels.values())
    
    fig, ax = plt.subplots(figsize = (6,6))
    
    disp.plot(ax = ax, cmap = 'Blues', xticks_rotation = 'vertical', colorbar=False)
    # Disable the grid
    ax.grid(False)

    plt.show();

# %%
###------------------------------------------------
### Plot Loss Curve using Tensorflow history object
###------------------------------------------------
def fn_plot_tf_hist(hist_df):
    
    '''
    Args:
        hist_df: a dataframe with following ccolumns
            column 0: loss
            column 1: accuracy
            column 2: val_loss
            column 3: val_accuracy
            While plotting columns are accessed by index 
            so that even if the column names are different it will not throw exceptions.
    '''
        
    fig, axes = plt.subplots(1,2 , figsize = (15,6))

    # properties  matplotlib.patch.Patch 
    props = dict(boxstyle='round', facecolor='aqua', alpha=0.4)
    facecolor = 'cyan'
    fontsize=12
    CMAP = plt.cm.coolwarm
    
    # Get columns by index to eliminate any column naming error
    y1 = hist_df.columns[0]
    y2 = hist_df.columns[1]
    y3 = hist_df.columns[2]
    y4 = hist_df.columns[3]

    # Where was min loss
    best = hist_df[hist_df[y3] == hist_df[y3].min()]
    
    ax = axes[0]

    hist_df.plot(y = [y1,y3], ax = ax, colormap=CMAP)


    # little beautification
    txtFmt = "Loss: \n  train: {:6.4f}\n   test: {:6.4f}"
    txtstr = txtFmt.format(hist_df.iloc[-1][y1],
                           hist_df.iloc[-1][y3]) #text to plot
    
    # place a text box in upper middle in axes coords
    ax.text(0.3, 0.95, txtstr, transform=ax.transAxes, fontsize=fontsize,
            verticalalignment='top', bbox=props)
    
    # calculate offset for arroe
    y_min = min(hist_df[y1].min(), hist_df[y3].min())
    y_max = max(hist_df[y1].max(), hist_df[y3].max())
    offset = (y_max-y_min)/10.0
    
    # Mark arrow at lowest
    ax.annotate(f'Min: {best[y3].to_numpy()[0]:6.4f}', # text to print
                xy=(best.index.to_numpy(), best[y3].to_numpy()[0]), # Arrow start
                xytext=(best.index.to_numpy(), best[y3].to_numpy()[0] + offset), # location of text 
                fontsize=fontsize, va='bottom', ha='right',bbox=props, # beautification of text
                arrowprops=dict(facecolor=facecolor, shrink=0.05)) # arrow

    # Draw vertical line at best value
    ax.axvline(x = best.index.to_numpy(), color = 'green', linestyle='-.', lw = 3);

    ax.set_xlabel("Epochs")
    ax.set_ylabel(y1.capitalize())
    ax.set_title('Errors')
    ax.grid();
    ax.legend(loc = 'upper left') # model legend to upper left

    ax = axes[1]

    hist_df.plot( y = [y2, y4], ax = ax, colormap=CMAP)
    
    # little beautification
    txtFmt = "Accuracy: \n  train: {:6.4f}\n  test:  {:6.4f}"
    txtstr = txtFmt.format(hist_df.iloc[-1][y2],
                           hist_df.iloc[-1][y4]) #text to plot

    # place a text box in upper middle in axes coords
    ax.text(0.3, 0.2, txtstr, transform=ax.transAxes, fontsize=fontsize,
            verticalalignment='top', bbox=props)

    # calculate offset for arroe
    y_min = min(hist_df[y2].min(), hist_df[y4].min())
    y_max = max(hist_df[y2].max(), hist_df[y4].max())
    offset = (y_max-y_min)/10.0

    # Mark arrow at lowest
    ax.annotate(f'Best: {best[y4].to_numpy()[0]:6.4f}', # text to print
                xy=(best.index.to_numpy(), best[y4].to_numpy()[0]), # Arrow start
                xytext=(best.index.to_numpy(), best[y4].to_numpy()[0]-offset), # location of text 
                fontsize=fontsize, va='bottom', ha='right',bbox=props, # beautification of text
                arrowprops=dict(facecolor=facecolor, shrink=0.05)) # arrow
    
    
    # Draw vertical line at best value
    ax.axvline(x = best.index.to_numpy(), color = 'green', linestyle='-.', lw = 3);

    ax.set_xlabel("Epochs")
    ax.set_ylabel(y2.capitalize())
    ax.grid()
    ax.legend(loc = 'lower left')
    
    plt.tight_layout()

# %% [markdown]
# ## Basic Hygiene

# %%
# Check if all directories are present
# if not os.path.exists(os.path.join(outDir)):
#     os.makedirs(os.path.join(outDir))
#     print ('Created {} directory'.format(outDir))

# if not os.path.exists(os.path.join(modelDir, subDir)):
#     os.makedirs(os.path.join(modelDir, subDir))
#     print ('Created {} directory'.format(os.path.join(modelDir, subDir)))

# %%
### Settings so that Tensorflow can not Hog all the GPU memory
physical_devices = tf.config.list_physical_devices('GPU') 

if len(physical_devices) > 0:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %% [markdown]
# ## Read FIFA 2019 data set

# %%
data_df = pd.read_csv('fifa_2019.csv')
data_df.shape
# Out:
# (18207, 89)

# %%
# removing rows with position = null
data_df = data_df[data_df["Position"].notnull()]
data_df.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
#                   Club  ... Composure Marking StandingTackle  SlidingTackle  \
# 0         FC Barcelona  ...      96.0    33.0           28.0           26.0
# 1             Juventus  ...      95.0    28.0           31.0           23.0
# 2  Paris Saint-Germain  ...      94.0    27.0           24.0           33.0
# 3    Manchester United  ...      68.0    15.0           21.0           13.0
# 4      Manchester City  ...      88.0    68.0           58.0           51.0
#
#   GKDiving  GKHandling  GKKicking  GKPositioning GKReflexes Release Clause
# 0      6.0        11.0       15.0           14.0        8.0        €226.5M
# 1      7.0        11.0       15.0           14.0       11.0        €127.1M
# 2      9.0         9.0       15.0           15.0       11.0        €228.1M
# 3     90.0        85.0       87.0           88.0       94.0        €138.6M
# 4     15.0        13.0        5.0           10.0       13.0        €196.4M
#
# [5 rows x 89 columns]

# %%
# Following columns appear to be relevant for our analysis
rel_cols = ['Position', 'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
            'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
            'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
            'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
            'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
            'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling',
            'GKKicking', 'GKPositioning', 'GKReflexes']

data_df = data_df[rel_cols]
data_df.head()
# Out:
#   Position  Finishing  HeadingAccuracy  ShortPassing  Volleys  Dribbling  \
# 0       RF       95.0             70.0          90.0     86.0       97.0
# 1       ST       94.0             89.0          81.0     87.0       88.0
# 2       LW       87.0             62.0          84.0     84.0       96.0
# 3       GK       13.0             21.0          50.0     13.0       18.0
# 4      RCM       82.0             55.0          92.0     82.0       86.0
#
#    Curve  FKAccuracy  LongPassing  BallControl  ...  Penalties  Composure  \
# 0   93.0        94.0         87.0         96.0  ...       75.0       96.0
# 1   81.0        76.0         77.0         94.0  ...       85.0       95.0
# 2   88.0        87.0         78.0         95.0  ...       81.0       94.0
# 3   21.0        19.0         51.0         42.0  ...       40.0       68.0
# 4   85.0        83.0         91.0         91.0  ...       79.0       88.0
#
#    Marking  StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# 0     33.0            28.0           26.0       6.0        11.0       15.0
# 1     28.0            31.0           23.0       7.0        11.0       15.0
# 2     27.0            24.0           33.0       9.0         9.0       15.0
# 3     15.0            21.0           13.0      90.0        85.0       87.0
# 4     68.0            58.0           51.0      15.0        13.0        5.0
#
#    GKPositioning  GKReflexes
# 0           14.0         8.0
# 1           14.0        11.0
# 2           15.0        11.0
# 3           88.0        94.0
# 4           10.0        13.0
#
# [5 rows x 34 columns]

# %%
# Are there NaNs Still?

data_df.isna().sum()
# Out:
# Position           0
# Finishing          0
# HeadingAccuracy    0
# ShortPassing       0
# Volleys            0
# Dribbling          0
# Curve              0
# FKAccuracy         0
# LongPassing        0
# BallControl        0
# Acceleration       0
# SprintSpeed        0
# Agility            0
# Reactions          0
# Balance            0
# ShotPower          0
# Jumping            0
# Stamina            0
# Strength           0
# LongShots          0
# Aggression         0
# Interceptions      0
# Positioning        0
# Vision             0
# Penalties          0
# Composure          0
# Marking            0
# StandingTackle     0
# SlidingTackle      0
# GKDiving           0
# GKHandling         0
# GKKicking          0
# GKPositioning      0
# GKReflexes         0
# dtype: int64

# %%
goalkeeper = 'GK'
forward = ['ST', 'LW', 'RW', 'LF', 'RF', 'RS','LS', 'CF']
midfielder = ['CM','RCM','LCM', 'CDM','RDM','LDM', 'CAM', 'LAM', 'RAM', 'RM', 'LM']
defender = ['CB', 'RCB', 'LCB', 'LWB', 'RWB', 'LB', 'RB']

# %%
#Assign labels to goalkeepers
data_df.loc[data_df["Position"] == "GK", "Position"] = 0

#Defenders
data_df.loc[data_df["Position"].isin(defender), "Position"] = 1

#Midfielders
data_df.loc[data_df["Position"].isin(midfielder), "Position"] = 2

#Forward
data_df.loc[data_df["Position"].isin(forward), "Position"] = 3

# Convert Column "Position" to numeric so that Pandas does not complain
data_df['Position'] = pd.to_numeric(data_df['Position'], downcast="integer")

# %%
class_labels = {0: 'Goal Keeper', 1: 'Defender', 2: 'Mid-Fielder', 3: 'Forward'}

# %%
y = data_df["Position"].to_numpy()

X = data_df.drop("Position", axis = 1)

# %%
#  Split the data in training and test sets to measure performance of the model.
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size=TEST_SIZE,
                                                    stratify=y,
                                                    random_state=RANDOM_STATE )

print (X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# (14517, 33) (14517,) (3630, 33) (3630,)

# %%
sc = StandardScaler()

X_train = sc.fit_transform(X_train)

X_test = sc.transform(X_test)

# %%
# y_train = y_train.to_numpy()
# y_test = y_test.numpy()

# %%
# 33 -> 23 -> 12 -> 4-> 4

# %%
k_init = tf.keras.initializers.GlorotUniform(seed=RANDOM_STATE)
dor1 = 0.05
dor2 = 0.10
dor3 = 0.20
dor4 = 0.20
k_reg = tf.keras.regularizers.L2(l2=REG_Lambda)
model = tf.keras.Sequential([
    # Input Layer 
    tf.keras.layers.InputLayer(input_shape=(33,)),
    # Set 1
    tf.keras.layers.Dense(33, 
                        #   activation='relu', 
                          kernel_initializer=k_init,kernel_regularizer=k_reg),
    # tf.keras.layers.Dropout(dor1),
    # BN Layer
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.ReLU(),
    # Set 2
    tf.keras.layers.Dense(23, 
                        #   activation='relu', 
                          kernel_initializer=k_init,kernel_regularizer=k_reg),
    # BN Layer                      
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.ReLU(),
    # tf.keras.layers.Dropout(dor2),
    # Set 3
    tf.keras.layers.Dense(12, 
                        #   activation='relu', 
                          kernel_initializer=k_init,kernel_regularizer=k_reg),
    # BN Layer
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.ReLU(),
    # tf.keras.layers.Dropout(dor3),
    # Set 4
    tf.keras.layers.Dense(4, 
                        #   activation='relu', 
                          kernel_initializer=k_init,kernel_regularizer=k_reg),
    # tf.keras.layers.Dropout(dor4),
    # BN Layer
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.ReLU(),
    tf.keras.layers.Dense(4)
])

# %% [markdown]
# ### Callbacks

# %%
checkpoint_path = os.path.join(modelDir, subDir, 'weights_tf_fifa')

model_checkpoint = tf.keras.callbacks.ModelCheckpoint(
    checkpoint_path,
    monitor='val_loss',
    verbose=2,
    save_best_only=True,
    save_weights_only=True,
    mode='auto',
    save_freq='epoch',
    initial_value_threshold=None
)

es_checkpoint = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=PATIENCE,
    verbose=2,
    mode='auto',
    restore_best_weights=True
)

lr_checkpoint = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=LR_FACTOR,
    patience=LR_PATIENCE,
    verbose=2,
    mode='auto',
    min_lr=0.00001
)

log_dir = os.path.join(logDir, 'fit')
tb_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

# %%
model(X_train[:1])
# Out:
# <tf.Tensor: shape=(1, 4), dtype=float32, numpy=
# array([[ 0.06045996, -0.07082363,  0.05698359,  0.1915563 ]],
#       dtype=float32)>

# %%
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

optimizer = tf.keras.optimizers.Adam(learning_rate=ALPHA)

# %%
model.compile(optimizer=optimizer, loss=loss_fn, metrics=['accuracy'])

history = model.fit(X_train, y_train, validation_data=[X_test, y_test],
                     batch_size=BATCH_SIZE, 
                     epochs=EPOCHS,
                      callbacks=[lr_checkpoint, model_checkpoint,
                                 es_checkpoint, tb_callback] , verbose=2)
# Out:
# Epoch 1/101
#
# Epoch 1: val_loss improved from inf to 0.55306, saving model to ../models\fifa_2019\weights_tf_fifa
# 454/454 - 7s - loss: 0.8969 - accuracy: 0.6830 - val_loss: 0.5531 - val_accuracy: 0.8537 - lr: 0.0010 - 7s/epoch - 14ms/step
# Epoch 2/101
#
# Epoch 2: val_loss improved from 0.55306 to 0.40028, saving model to ../models\fifa_2019\weights_tf_fifa
# 454/454 - 2s - loss: 0.4897 - accuracy: 0.8504 - val_loss: 0.4003 - val_accuracy: 0.8716 - lr: 0.0010 - 2s/epoch - 5ms/step
# Epoch 3/101
#
# Epoch 3: val_loss improved from 0.40028 to 0.37440, saving model to ../models\fifa_2019\weights_tf_fifa
# 454/454 - 3s - loss: 0.4189 - accuracy: 0.8567 - val_loss: 0.3744 - val_accuracy: 0.8675 - lr: 0.0010 - 3s/epoch - 6ms/step
# Epoch 4/101
#
# Epoch 4: val_loss improved from 0.37440 to 0.35579, saving model to ../models\fifa_2019\weights_tf_fifa
# 454/454 - 3s - loss: 0.3889 - accuracy: 0.8640 - val_loss: 0.3558 - val_accuracy: 0.8755 - lr: 0.0010 - 3s/epoch - 7ms/step
# Epoch 5/101
#
# Epoch 5: val_loss improved from 0.35579 to 0.35513, saving model to ../models\fifa_2019\weights_tf_fifa
# 454/454 - 3s - loss: 0.3727 - accuracy: 0.8640 - val_loss: 0.3551 - val_accuracy: 0.8697 - lr: 0.0010 - 3s/epoch - 7ms/step
# Epoch 6/101
#
# Epoch 6: val_loss improved from 0.35513 to 0.34003, saving model to ../models\fifa_2019\weights_tf_fifa
# 454/454 - 3s - loss: 0.3725 - accuracy: 0.8663 - val_loss: 0.3400 - val_accuracy: 0.8763 - lr: 0.0010 - 3s/epoch - 6ms/step
# Epoch 7/101
#
# Epoch 7: val_loss improved from 0.34003 to 0.33423, saving model to ../models\fifa_2019\weights_tf_fifa
# 454/454 - 3s - loss: 0.3554 - accuracy: 0.8691 - val_loss: 0.3342 - val_accuracy: 0.8771 - lr: 0.0010 - 3s/epoch - 6ms/step
# Epoch 8/101
#
# Epoch 8: val_loss did not improve from 0.33423
# 454/454 - 3s - loss: 0.3523 - accuracy: 0.8696 - val_loss: 0.3366 - val_accuracy: 0.8793 - lr: 0.0010 - 3s/epoch - 6ms/step
# Epoch 9/101
#
# Epoch 9: val_loss did not improve from 0.33423
# 454/454 - 3s - loss: 0.3491 - accuracy: 0.8677 - val_loss: 0.3421 - val_accuracy: 0.8661 - lr: 0.0010 - 3s/epoch - 6ms/step
# Epoch 10/101
#
# Epoch 10: val_loss improved from 0.33423 to 0.33155, saving model to ../models\fifa_2019\weights_tf_fifa
# 454/454 - 3s - loss: 0.3450 - accuracy: 0.8737 - val_loss: 0.3316 - val_accuracy: 0.8744 - lr: 0.0010 - 3s/epoch - 6ms/step
# Epoch 11/101
#
# Epoch 11: val_loss improved from 0.33155 to 0.32439, saving model to ../models\fifa_2019\weights_tf_fifa
# 454/454 - 3s - loss: 0.3493 - accuracy: 0.8695 - val_loss: 0.3244 - val_accuracy: 0.8791 - lr: 0.0010 - 3s/epoch - 6ms/step
# Epoch 12/101
#
# Epoch 12: val_loss did not improve from 0.32439
# 454/454 - 2s - loss: 0.3382 - accuracy: 0.8721 - val_loss: 0.3249 - val_accuracy: 0.8782 - lr: 0.0010 - 2s/epoch - 5ms/step
# Epoch 13/101
#
# Epoch 13: val_loss did not improve from 0.32439
# 454/454 - 3s - loss: 0.3368 - accuracy: 0.8718 - val_loss: 0.3255 - val_accuracy: 0.8780 - lr: 0.0010 - 3s/epoch - 6ms/step
# Epoch 14/101
#
# Epoch 14: val_loss improved from 0.32439 to 0.32296, saving model to ../models\fifa_2019\weights_tf_fifa
# 454/454 - 3s - loss: 0.3371 - accuracy: 0.8734 - val_loss: 0.3230 - val_accuracy: 0.8780 - lr: 0.0010 - 3s/epoch - 7ms/step
# Epoch 15/101
#
# Epoch 15: val_loss improved from 0.32296 to 0.32132, saving model to ../models\fifa_2019\weights_tf_fifa
# 454/454 - 3s - loss: 0.3290 - accuracy: 0.8748 - val_loss: 0.3213 - val_accuracy: 0.8777 - lr: 0.0010 - 3s/epoch - 6ms/step
# Epoch 16/101
#
# Epoch 16: val_loss improved from 0.32132 to 0.32123, saving model to ../models\fifa_2019\weights_tf_fifa
# 454/454 - 3s - loss: 0.3280 - accuracy: 0.8739 - val_loss: 0.3212 - val_accuracy: 0.8741 - lr: 0.0010 - 3s/epoch - 6ms/step
# Epoch 17/101
#
# Epoch 17: val_loss did not improve from 0.32123
# 454/454 - 3s - loss: 0.3310 - accuracy: 0.8742 - val_loss: 0.3372 - val_accuracy: 0.8617 - lr: 0.0010 - 3s/epoch - 6ms/step
# Epoch 18/101
#
# Epoch 18: val_loss improved from 0.32123 to 0.31934, saving model to ../models\fifa_2019\weights_tf_fifa
# 454/454 - 3s - loss: 0.3290 - accuracy: 0.8739 - val_loss: 0.3193 - val_accuracy: 0.8702 - lr: 0.0010 - 3s/epoch - 6ms/step
# Epoch 19/101
#
# Epoch 19: val_loss did not improve from 0.31934
# 454/454 - 3s - loss: 0.3232 - accuracy: 0.8772 - val_loss: 0.3204 - val_accuracy: 0.8733 - lr: 0.0010 - 3s/epoch - 6ms/step
# Epoch 20/101
#
# Epoch 20: val_loss did not improve from 0.31934
# 454/454 - 3s - loss: 0.3226 - accuracy: 0.8747 - val_loss: 0.3199 - val_accuracy: 0.8782 - lr: 0.0010 - 3s/epoch - 6ms/step
# Epoch 21/101
#
# Epoch 21: val_loss did not improve from 0.31934
# 454/454 - 3s - loss: 0.3214 - accuracy: 0.8790 - val_loss: 0.3238 - val_accuracy: 0.8774 - lr: 0.0010 - 3s/epoch - 6ms/step
# Epoch 22/101
#
# Epoch 22: val_loss did not improve from 0.31934
# 454/454 - 3s - loss: 0.3218 - accuracy: 0.8752 - val_loss: 0.3303 - val_accuracy: 0.8672 - lr: 0.0010 - 3s/epoch - 6ms/step
# Epoch 23/101
#
# Epoch 23: val_loss did not improve from 0.31934
# 454/454 - 3s - loss: 0.3196 - accuracy: 0.8773 - val_loss: 0.3211 - val_accuracy: 0.8766 - lr: 0.0010 - 3s/epoch - 6ms/step
# Epoch 24/101
#
# Epoch 24: val_loss did not improve from 0.31934
# 454/454 - 3s - loss: 0.3188 - accuracy: 0.8788 - val_loss: 0.3210 - val_accuracy: 0.8719 - lr: 0.0010 - 3s/epoch - 6ms/step
# Epoch 25/101
#
# Epoch 25: val_loss did not improve from 0.31934
# 454/454 - 3s - loss: 0.3159 - accuracy: 0.8774 - val_loss: 0.3232 - val_accuracy: 0.8755 - lr: 0.0010 - 3s/epoch - 6ms/step
# Epoch 26/101
#
# Epoch 26: val_loss did not improve from 0.31934
# 454/454 - 3s - loss: 0.3144 - accuracy: 0.8786 - val_loss: 0.3286 - val_accuracy: 0.8664 - lr: 0.0010 - 3s/epoch - 6ms/step
# Epoch 27/101
#
# Epoch 27: val_loss improved from 0.31934 to 0.31889, saving model to ../models\fifa_2019\weights_tf_fifa
# 454/454 - 3s - loss: 0.3157 - accuracy: 0.8770 - val_loss: 0.3189 - val_accuracy: 0.8738 - lr: 0.0010 - 3s/epoch - 7ms/step
# Epoch 28/101
#
# Epoch 28: val_loss did not improve from 0.31889
# 454/454 - 3s - loss: 0.3149 - accuracy: 0.8779 - val_loss: 0.3228 - val_accuracy: 0.8755 - lr: 0.0010 - 3s/epoch - 6ms/step
# Epoch 29/101
#
# Epoch 29: val_loss did not improve from 0.31889
# 454/454 - 3s - loss: 0.3184 - accuracy: 0.8788 - val_loss: 0.3297 - val_accuracy: 0.8733 - lr: 0.0010 - 3s/epoch - 6ms/step
# Epoch 30/101
#
# Epoch 30: val_loss did not improve from 0.31889
# 454/454 - 3s - loss: 0.3104 - accuracy: 0.8800 - val_loss: 0.3212 - val_accuracy: 0.8711 - lr: 0.0010 - 3s/epoch - 6ms/step
# Epoch 31/101
#
# Epoch 31: val_loss did not improve from 0.31889
# 454/454 - 3s - loss: 0.3112 - accuracy: 0.8791 - val_loss: 0.3227 - val_accuracy: 0.8727 - lr: 0.0010 - 3s/epoch - 6ms/step
# Epoch 32/101
#
# Epoch 32: val_loss did not improve from 0.31889
# 454/454 - 3s - loss: 0.3117 - accuracy: 0.8772 - val_loss: 0.3238 - val_accuracy: 0.8722 - lr: 0.0010 - 3s/epoch - 6ms/step
# Epoch 33/101
#
# Epoch 33: val_loss did not improve from 0.31889
# 454/454 - 3s - loss: 0.3151 - accuracy: 0.8790 - val_loss: 0.3281 - val_accuracy: 0.8747 - lr: 0.0010 - 3s/epoch - 6ms/step
# Epoch 34/101
#
# Epoch 34: val_loss did not improve from 0.31889
# 454/454 - 3s - loss: 0.3087 - accuracy: 0.8800 - val_loss: 0.3204 - val_accuracy: 0.8736 - lr: 0.0010 - 3s/epoch - 6ms/step
# Epoch 35/101
#
# Epoch 35: val_loss did not improve from 0.31889
# 454/454 - 2s - loss: 0.3089 - accuracy: 0.8795 - val_loss: 0.3214 - val_accuracy: 0.8747 - lr: 0.0010 - 2s/epoch - 5ms/step
# Epoch 36/101
#
# Epoch 36: val_loss improved from 0.31889 to 0.31717, saving model to ../models\fifa_2019\weights_tf_fifa
# 454/454 - 3s - loss: 0.3111 - accuracy: 0.8790 - val_loss: 0.3172 - val_accuracy: 0.8755 - lr: 0.0010 - 3s/epoch - 6ms/step
# Epoch 37/101
#
# Epoch 37: val_loss did not improve from 0.31717
# 454/454 - 3s - loss: 0.3069 - accuracy: 0.8806 - val_loss: 0.3244 - val_accuracy: 0.8700 - lr: 0.0010 - 3s/epoch - 6ms/step
# Epoch 38/101
#
# Epoch 38: val_loss did not improve from 0.31717
# 454/454 - 3s - loss: 0.3053 - accuracy: 0.8821 - val_loss: 0.3228 - val_accuracy: 0.8625 - lr: 0.0010 - 3s/epoch - 6ms/step
# Epoch 39/101
#
# Epoch 39: val_loss did not improve from 0.31717
# 454/454 - 3s - loss: 0.3082 - accuracy: 0.8791 - val_loss: 0.3259 - val_accuracy: 0.8749 - lr: 0.0010 - 3s/epoch - 6ms/step
# Epoch 40/101
#
# Epoch 40: val_loss did not improve from 0.31717
# 454/454 - 3s - loss: 0.3080 - accuracy: 0.8794 - val_loss: 0.3278 - val_accuracy: 0.8658 - lr: 0.0010 - 3s/epoch - 6ms/step
# Epoch 41/101
#
# Epoch 41: val_loss did not improve from 0.31717
# 454/454 - 2s - loss: 0.3095 - accuracy: 0.8799 - val_loss: 0.3286 - val_accuracy: 0.8730 - lr: 0.0010 - 2s/epoch - 5ms/step
# Epoch 42/101
#
# Epoch 42: val_loss did not improve from 0.31717
# 454/454 - 3s - loss: 0.3043 - accuracy: 0.8828 - val_loss: 0.3316 - val_accuracy: 0.8730 - lr: 0.0010 - 3s/epoch - 6ms/step
# Epoch 43/101
#
# Epoch 43: val_loss did not improve from 0.31717
# 454/454 - 3s - loss: 0.3083 - accuracy: 0.8794 - val_loss: 0.3238 - val_accuracy: 0.8733 - lr: 0.0010 - 3s/epoch - 6ms/step
# Epoch 44/101
#
# Epoch 44: val_loss did not improve from 0.31717
# 454/454 - 3s - loss: 0.3037 - accuracy: 0.8828 - val_loss: 0.3223 - val_accuracy: 0.8653 - lr: 0.0010 - 3s/epoch - 6ms/step
# Epoch 45/101
#
# Epoch 45: val_loss did not improve from 0.31717
# 454/454 - 3s - loss: 0.3048 - accuracy: 0.8834 - val_loss: 0.3271 - val_accuracy: 0.8777 - lr: 0.0010 - 3s/epoch - 6ms/step
# Epoch 46/101
#
# Epoch 46: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 46: val_loss did not improve from 0.31717
# 454/454 - 3s - loss: 0.3075 - accuracy: 0.8811 - val_loss: 0.3197 - val_accuracy: 0.8771 - lr: 0.0010 - 3s/epoch - 6ms/step
# Epoch 47/101
#
# Epoch 47: val_loss improved from 0.31717 to 0.31708, saving model to ../models\fifa_2019\weights_tf_fifa
# 454/454 - 3s - loss: 0.2966 - accuracy: 0.8862 - val_loss: 0.3171 - val_accuracy: 0.8741 - lr: 1.0000e-04 - 3s/epoch - 6ms/step
# Epoch 48/101
#
# Epoch 48: val_loss did not improve from 0.31708
# 454/454 - 3s - loss: 0.2903 - accuracy: 0.8865 - val_loss: 0.3179 - val_accuracy: 0.8727 - lr: 1.0000e-04 - 3s/epoch - 6ms/step
# Epoch 49/101
#
# Epoch 49: val_loss did not improve from 0.31708
# 454/454 - 3s - loss: 0.2892 - accuracy: 0.8870 - val_loss: 0.3183 - val_accuracy: 0.8755 - lr: 1.0000e-04 - 3s/epoch - 6ms/step
# Epoch 50/101
#
# Epoch 50: val_loss did not improve from 0.31708
# 454/454 - 2s - loss: 0.2898 - accuracy: 0.8882 - val_loss: 0.3196 - val_accuracy: 0.8730 - lr: 1.0000e-04 - 2s/epoch - 5ms/step
# Epoch 51/101
#
# Epoch 51: val_loss did not improve from 0.31708
# 454/454 - 3s - loss: 0.2859 - accuracy: 0.8892 - val_loss: 0.3179 - val_accuracy: 0.8744 - lr: 1.0000e-04 - 3s/epoch - 6ms/step
# Epoch 52/101
#
# Epoch 52: val_loss did not improve from 0.31708
# 454/454 - 2s - loss: 0.2826 - accuracy: 0.8888 - val_loss: 0.3194 - val_accuracy: 0.8747 - lr: 1.0000e-04 - 2s/epoch - 5ms/step
# Epoch 53/101
#
# Epoch 53: val_loss did not improve from 0.31708
# 454/454 - 3s - loss: 0.2824 - accuracy: 0.8907 - val_loss: 0.3205 - val_accuracy: 0.8733 - lr: 1.0000e-04 - 3s/epoch - 6ms/step
# Epoch 54/101
#
# Epoch 54: val_loss did not improve from 0.31708
# 454/454 - 3s - loss: 0.2817 - accuracy: 0.8904 - val_loss: 0.3205 - val_accuracy: 0.8711 - lr: 1.0000e-04 - 3s/epoch - 6ms/step
# Epoch 55/101
#
# Epoch 55: val_loss did not improve from 0.31708
# 454/454 - 3s - loss: 0.2812 - accuracy: 0.8911 - val_loss: 0.3218 - val_accuracy: 0.8744 - lr: 1.0000e-04 - 3s/epoch - 7ms/step
# Epoch 56/101
#
# Epoch 56: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 56: val_loss did not improve from 0.31708
# 454/454 - 3s - loss: 0.2810 - accuracy: 0.8902 - val_loss: 0.3218 - val_accuracy: 0.8736 - lr: 1.0000e-04 - 3s/epoch - 6ms/step
# Epoch 57/101
#
# Epoch 57: val_loss did not improve from 0.31708
# 454/454 - 3s - loss: 0.2780 - accuracy: 0.8930 - val_loss: 0.3215 - val_accuracy: 0.8749 - lr: 1.0000e-05 - 3s/epoch - 6ms/step
# Epoch 58/101
#
# Epoch 58: val_loss did not improve from 0.31708
# 454/454 - 3s - loss: 0.2784 - accuracy: 0.8925 - val_loss: 0.3218 - val_accuracy: 0.8738 - lr: 1.0000e-05 - 3s/epoch - 6ms/step
# Epoch 59/101
#
# Epoch 59: val_loss did not improve from 0.31708
# 454/454 - 3s - loss: 0.2810 - accuracy: 0.8907 - val_loss: 0.3209 - val_accuracy: 0.8747 - lr: 1.0000e-05 - 3s/epoch - 6ms/step
# Epoch 60/101
#
# Epoch 60: val_loss did not improve from 0.31708
# 454/454 - 3s - loss: 0.2811 - accuracy: 0.8895 - val_loss: 0.3215 - val_accuracy: 0.8719 - lr: 1.0000e-05 - 3s/epoch - 6ms/step
# Epoch 61/101
#
# Epoch 61: val_loss did not improve from 0.31708
# 454/454 - 3s - loss: 0.2800 - accuracy: 0.8912 - val_loss: 0.3214 - val_accuracy: 0.8716 - lr: 1.0000e-05 - 3s/epoch - 6ms/step
# Epoch 62/101
#
# Epoch 62: val_loss did not improve from 0.31708
# 454/454 - 3s - loss: 0.2784 - accuracy: 0.8907 - val_loss: 0.3214 - val_accuracy: 0.8725 - lr: 1.0000e-05 - 3s/epoch - 6ms/step
# Epoch 63/101
#
# Epoch 63: val_loss did not improve from 0.31708
# 454/454 - 3s - loss: 0.2775 - accuracy: 0.8918 - val_loss: 0.3217 - val_accuracy: 0.8733 - lr: 1.0000e-05 - 3s/epoch - 6ms/step
# Epoch 64/101
#
# Epoch 64: val_loss did not improve from 0.31708
# 454/454 - 3s - loss: 0.2801 - accuracy: 0.8883 - val_loss: 0.3211 - val_accuracy: 0.8730 - lr: 1.0000e-05 - 3s/epoch - 6ms/step
# Epoch 65/101
#
# Epoch 65: val_loss did not improve from 0.31708
# 454/454 - 3s - loss: 0.2783 - accuracy: 0.8916 - val_loss: 0.3214 - val_accuracy: 0.8733 - lr: 1.0000e-05 - 3s/epoch - 6ms/step
# Epoch 66/101
#
# Epoch 66: ReduceLROnPlateau reducing learning rate to 1e-05.
#
# Epoch 66: val_loss did not improve from 0.31708
# 454/454 - 3s - loss: 0.2786 - accuracy: 0.8921 - val_loss: 0.3215 - val_accuracy: 0.8727 - lr: 1.0000e-05 - 3s/epoch - 6ms/step
# Epoch 67/101
#
# Epoch 67: val_loss did not improve from 0.31708
# Restoring model weights from the end of the best epoch: 47.
# 454/454 - 3s - loss: 0.2784 - accuracy: 0.8904 - val_loss: 0.3217 - val_accuracy: 0.8716 - lr: 1.0000e-05 - 3s/epoch - 6ms/step
# Epoch 67: early stopping

# %%
fn_plot_tf_hist(pd.DataFrame(history.history))

# %%
loss_df = pd.DataFrame(history.history)
loss_df[loss_df['val_loss'] == loss_df['val_loss'].min()]
# Out:
#         loss  accuracy  val_loss  val_accuracy      lr
# 46  0.296616  0.886202  0.317079      0.874105  0.0001

# %%
model.evaluate(X_test, y_test)
# Out:
# 114/114 [==============================] - 0s 3ms/step - loss: 0.3171 - accuracy: 0.8741
# [0.31707948446273804, 0.8741046786308289]
