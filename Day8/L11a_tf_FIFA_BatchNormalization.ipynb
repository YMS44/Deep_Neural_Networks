# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

# %% [markdown]
# # Deep Neural Networks
# ## Session 011
#
# ## Working with Tensorflow
# - One hidden layer
# - ${Swish}$ activation function
# - Adam
# - Multi-class output
# - FIFA dataset
#
# <img src='../../prasami_images/prasami_color_tutorials_small.png' width='400' alt="By Pramod Sharma : pramod.sharma@prasami.com" align="left"/>

# %%
###-----------------
### Import Libraries
###-----------------

import os
import sys
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
from time import time
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, ConfusionMatrixDisplay
from sklearn.preprocessing import StandardScaler

import tensorflow as tf

# from utils.helper import fn_plot_tf_hist, fn_plot_confusion_matrix
# Out:
# WARNING:tensorflow:From c:\Users\Administrator.DAI-PC2\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
###----------------------
### Some basic parameters
###----------------------

inpDir = '../../input' # location where input data is stored
outDir = '../output' # location to store outputs
modelDir = '../models' # location of the images
subDir = 'fifa_2019'

RANDOM_STATE = 24 # for initialization ----- REMEMBER: to remove at the time of promotion to production
np.random.seed(RANDOM_STATE) # Set Random Seed for reproducible  results
tf.random.set_seed(RANDOM_STATE) # setting for Tensorflow as well


EPOCHS = 101 # number of epochs
ALPHA = 0.001 # learning rate

BATCH_SIZE = 32
REG_Lambda = 0.001
TEST_SIZE = 0.2

PATIENCE = 20
LR_PATIENCE = 10
LR_FACTOR = 0.1

# Set parameters for decoration of plots
params = {'legend.fontsize' : 'medium',
          'figure.figsize'  : (15,6),
          'axes.labelsize'  : 'large',
          'axes.titlesize'  :'large',
          'xtick.labelsize' :'medium',
          'ytick.labelsize' :'medium',
         }

CMAP = plt.cm.coolwarm

plt.rcParams.update(params) # update rcParams

plt.style.use('seaborn-v0_8-darkgrid') # plt.style.use('ggplot')

# %%
###----------------------
### Plot confusion matrix
###----------------------
def fn_plot_confusion_matrix(y_true, y_pred, labels):
    '''
    Args:
        y_true: Ground Truth 
        y_pred : Predictions
        labels : dictonary 
                  {0: 'Goal Keeper', 
                  1: 'Defender', 
                  2: 'Mid-Fielder', 
                  3: 'Forward'}
    
    '''
    
    cm  = confusion_matrix(y_true, y_pred)
    
    disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                                  display_labels=labels.values())
    
    fig, ax = plt.subplots(figsize = (6,6))
    
    disp.plot(ax = ax, cmap = 'Blues', xticks_rotation = 'vertical', colorbar=False)
    # Disable the grid
    ax.grid(False)

    plt.show();

# %%
###------------------------------------------------
### Plot Loss Curve using Tensorflow history object
###------------------------------------------------
def fn_plot_tf_hist(hist_df):
    
    '''
    Args:
        hist_df: a dataframe with following ccolumns
            column 0: loss
            column 1: accuracy
            column 2: val_loss
            column 3: val_accuracy
            While plotting columns are accessed by index 
            so that even if the column names are different it will not throw exceptions.
    '''
        
    fig, axes = plt.subplots(1,2 , figsize = (15,6))

    # properties  matplotlib.patch.Patch 
    props = dict(boxstyle='round', facecolor='aqua', alpha=0.4)
    facecolor = 'cyan'
    fontsize=12
    CMAP = plt.cm.coolwarm
    
    # Get columns by index to eliminate any column naming error
    y1 = hist_df.columns[0]
    y2 = hist_df.columns[1]
    y3 = hist_df.columns[2]
    y4 = hist_df.columns[3]

    # Where was min loss
    best = hist_df[hist_df[y3] == hist_df[y3].min()]
    
    ax = axes[0]

    hist_df.plot(y = [y1,y3], ax = ax, colormap=CMAP)


    # little beautification
    txtFmt = "Loss: \n  train: {:6.4f}\n   test: {:6.4f}"
    txtstr = txtFmt.format(hist_df.iloc[-1][y1],
                           hist_df.iloc[-1][y3]) #text to plot
    
    # place a text box in upper middle in axes coords
    ax.text(0.3, 0.95, txtstr, transform=ax.transAxes, fontsize=fontsize,
            verticalalignment='top', bbox=props)
    
    # calculate offset for arroe
    y_min = min(hist_df[y1].min(), hist_df[y3].min())
    y_max = max(hist_df[y1].max(), hist_df[y3].max())
    offset = (y_max-y_min)/10.0
    
    # Mark arrow at lowest
    ax.annotate(f'Min: {best[y3].to_numpy()[0]:6.4f}', # text to print
                xy=(best.index.to_numpy(), best[y3].to_numpy()[0]), # Arrow start
                xytext=(best.index.to_numpy(), best[y3].to_numpy()[0] + offset), # location of text 
                fontsize=fontsize, va='bottom', ha='right',bbox=props, # beautification of text
                arrowprops=dict(facecolor=facecolor, shrink=0.05)) # arrow

    # Draw vertical line at best value
    ax.axvline(x = best.index.to_numpy(), color = 'green', linestyle='-.', lw = 3);

    ax.set_xlabel("Epochs")
    ax.set_ylabel(y1.capitalize())
    ax.set_title('Errors')
    ax.grid();
    ax.legend(loc = 'upper left') # model legend to upper left

    ax = axes[1]

    hist_df.plot( y = [y2, y4], ax = ax, colormap=CMAP)
    
    # little beautification
    txtFmt = "Accuracy: \n  train: {:6.4f}\n  test:  {:6.4f}"
    txtstr = txtFmt.format(hist_df.iloc[-1][y2],
                           hist_df.iloc[-1][y4]) #text to plot

    # place a text box in upper middle in axes coords
    ax.text(0.3, 0.2, txtstr, transform=ax.transAxes, fontsize=fontsize,
            verticalalignment='top', bbox=props)

    # calculate offset for arroe
    y_min = min(hist_df[y2].min(), hist_df[y4].min())
    y_max = max(hist_df[y2].max(), hist_df[y4].max())
    offset = (y_max-y_min)/10.0

    # Mark arrow at lowest
    ax.annotate(f'Best: {best[y4].to_numpy()[0]:6.4f}', # text to print
                xy=(best.index.to_numpy(), best[y4].to_numpy()[0]), # Arrow start
                xytext=(best.index.to_numpy(), best[y4].to_numpy()[0]-offset), # location of text 
                fontsize=fontsize, va='bottom', ha='right',bbox=props, # beautification of text
                arrowprops=dict(facecolor=facecolor, shrink=0.05)) # arrow
    
    
    # Draw vertical line at best value
    ax.axvline(x = best.index.to_numpy(), color = 'green', linestyle='-.', lw = 3);

    ax.set_xlabel("Epochs")
    ax.set_ylabel(y2.capitalize())
    ax.grid()
    ax.legend(loc = 'lower left')
    
    plt.tight_layout()

# %% [markdown]
# ## Basic Hygiene

# %%
# Check if all directories are present
# if not os.path.exists(os.path.join(outDir)):
#     os.makedirs(os.path.join(outDir))
#     print ('Created {} directory'.format(outDir))

# if not os.path.exists(os.path.join(modelDir, subDir)):
#     os.makedirs(os.path.join(modelDir, subDir))
#     print ('Created {} directory'.format(os.path.join(modelDir, subDir)))

# %%
### Settings so that Tensorflow can not Hog all the GPU memory
physical_devices = tf.config.list_physical_devices('GPU') 

if len(physical_devices) > 0:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %% [markdown]
# ## Read FIFA 2019 data set

# %%
data_df = pd.read_csv('fifa_2019.csv')
data_df.shape
# Out:
# (18207, 89)

# %%
# removing rows with position = null
data_df = data_df[data_df["Position"].notnull()]
data_df.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
#                   Club  ... Composure Marking StandingTackle  SlidingTackle  \
# 0         FC Barcelona  ...      96.0    33.0           28.0           26.0
# 1             Juventus  ...      95.0    28.0           31.0           23.0
# 2  Paris Saint-Germain  ...      94.0    27.0           24.0           33.0
# 3    Manchester United  ...      68.0    15.0           21.0           13.0
# 4      Manchester City  ...      88.0    68.0           58.0           51.0
#
#   GKDiving  GKHandling  GKKicking  GKPositioning GKReflexes Release Clause
# 0      6.0        11.0       15.0           14.0        8.0        €226.5M
# 1      7.0        11.0       15.0           14.0       11.0        €127.1M
# 2      9.0         9.0       15.0           15.0       11.0        €228.1M
# 3     90.0        85.0       87.0           88.0       94.0        €138.6M
# 4     15.0        13.0        5.0           10.0       13.0        €196.4M
#
# [5 rows x 89 columns]

# %%
# Following columns appear to be relevant for our analysis
rel_cols = ['Position', 'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
            'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
            'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
            'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
            'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
            'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling',
            'GKKicking', 'GKPositioning', 'GKReflexes']

data_df = data_df[rel_cols]
data_df.head()
# Out:
#   Position  Finishing  HeadingAccuracy  ShortPassing  Volleys  Dribbling  \
# 0       RF       95.0             70.0          90.0     86.0       97.0
# 1       ST       94.0             89.0          81.0     87.0       88.0
# 2       LW       87.0             62.0          84.0     84.0       96.0
# 3       GK       13.0             21.0          50.0     13.0       18.0
# 4      RCM       82.0             55.0          92.0     82.0       86.0
#
#    Curve  FKAccuracy  LongPassing  BallControl  ...  Penalties  Composure  \
# 0   93.0        94.0         87.0         96.0  ...       75.0       96.0
# 1   81.0        76.0         77.0         94.0  ...       85.0       95.0
# 2   88.0        87.0         78.0         95.0  ...       81.0       94.0
# 3   21.0        19.0         51.0         42.0  ...       40.0       68.0
# 4   85.0        83.0         91.0         91.0  ...       79.0       88.0
#
#    Marking  StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# 0     33.0            28.0           26.0       6.0        11.0       15.0
# 1     28.0            31.0           23.0       7.0        11.0       15.0
# 2     27.0            24.0           33.0       9.0         9.0       15.0
# 3     15.0            21.0           13.0      90.0        85.0       87.0
# 4     68.0            58.0           51.0      15.0        13.0        5.0
#
#    GKPositioning  GKReflexes
# 0           14.0         8.0
# 1           14.0        11.0
# 2           15.0        11.0
# 3           88.0        94.0
# 4           10.0        13.0
#
# [5 rows x 34 columns]

# %%
# Are there NaNs Still?

data_df.isna().sum()
# Out:
# Position           0
# Finishing          0
# HeadingAccuracy    0
# ShortPassing       0
# Volleys            0
# Dribbling          0
# Curve              0
# FKAccuracy         0
# LongPassing        0
# BallControl        0
# Acceleration       0
# SprintSpeed        0
# Agility            0
# Reactions          0
# Balance            0
# ShotPower          0
# Jumping            0
# Stamina            0
# Strength           0
# LongShots          0
# Aggression         0
# Interceptions      0
# Positioning        0
# Vision             0
# Penalties          0
# Composure          0
# Marking            0
# StandingTackle     0
# SlidingTackle      0
# GKDiving           0
# GKHandling         0
# GKKicking          0
# GKPositioning      0
# GKReflexes         0
# dtype: int64

# %%
goalkeeper = 'GK'
forward = ['ST', 'LW', 'RW', 'LF', 'RF', 'RS','LS', 'CF']
midfielder = ['CM','RCM','LCM', 'CDM','RDM','LDM', 'CAM', 'LAM', 'RAM', 'RM', 'LM']
defender = ['CB', 'RCB', 'LCB', 'LWB', 'RWB', 'LB', 'RB']

# %%
#Assign labels to goalkeepers
data_df.loc[data_df["Position"] == "GK", "Position"] = 0

#Defenders
data_df.loc[data_df["Position"].isin(defender), "Position"] = 1

#Midfielders
data_df.loc[data_df["Position"].isin(midfielder), "Position"] = 2

#Forward
data_df.loc[data_df["Position"].isin(forward), "Position"] = 3

# Convert Column "Position" to numeric so that Pandas does not complain
data_df['Position'] = pd.to_numeric(data_df['Position'], downcast="integer")

# %%
class_labels = {0: 'Goal Keeper', 1: 'Defender', 2: 'Mid-Fielder', 3: 'Forward'}

# %%
y = data_df["Position"].to_numpy()

X = data_df.drop("Position", axis = 1)

# %%
#  Split the data in training and test sets to measure performance of the model.
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size=TEST_SIZE,
                                                    stratify=y,
                                                    random_state=RANDOM_STATE )

print (X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# (14517, 33) (14517,) (3630, 33) (3630,)

# %%
sc = StandardScaler()

X_train = sc.fit_transform(X_train)

X_test = sc.transform(X_test)

# %%
# y_train = y_train.to_numpy()
# y_test = y_test.numpy()

# %%
# 33 -> 23 -> 12 -> 4-> 4

# %%
k_init = tf.keras.initializers.GlorotUniform(seed=RANDOM_STATE)
dor1 = 0.05
dor2 = 0.10
dor3 = 0.20
dor4 = 0.20
k_reg = tf.keras.regularizers.L2(l2=REG_Lambda)
model = tf.keras.Sequential([
    # Input Layer 
    tf.keras.layers.InputLayer(input_shape=(33,)),
    # Set 1
    tf.keras.layers.Dense(33, 
                        #   activation='relu', 
                          kernel_initializer=k_init,kernel_regularizer=k_reg),
    # tf.keras.layers.Dropout(dor1),
    # BN Layer
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.ReLU(),
    # Set 2
    tf.keras.layers.Dense(23, 
                        #   activation='relu', 
                          kernel_initializer=k_init,kernel_regularizer=k_reg),
    # BN Layer                      
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.ReLU(),
    # tf.keras.layers.Dropout(dor2),
    # Set 3
    tf.keras.layers.Dense(12, 
                        #   activation='relu', 
                          kernel_initializer=k_init,kernel_regularizer=k_reg),
    # BN Layer
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.ReLU(),
    # tf.keras.layers.Dropout(dor3),
    # Set 4
    tf.keras.layers.Dense(4, 
                        #   activation='relu', 
                          kernel_initializer=k_init,kernel_regularizer=k_reg),
    # tf.keras.layers.Dropout(dor4),
    # BN Layer
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.ReLU(),
    tf.keras.layers.Dense(4)
])
# Out:
# WARNING:tensorflow:From c:\Users\Administrator.DAI-PC2\anaconda3\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.

# %%
model(X_train[:1])
# Out:
# <tf.Tensor: shape=(1, 4), dtype=float32, numpy=
# array([[ 0.11099439, -0.14928968,  0.29773498,  0.10196977]],
#       dtype=float32)>

# %%
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

optimizer = tf.keras.optimizers.Adam(learning_rate=ALPHA)

# %%
model.compile(optimizer=optimizer, loss=loss_fn, metrics=['accuracy'])

history = model.fit(X_train, y_train, validation_data=[X_test, y_test],
                     batch_size=BATCH_SIZE, 
                     epochs=EPOCHS, verbose=2)
# Out:
# Epoch 1/101
# WARNING:tensorflow:From c:\Users\Administrator.DAI-PC2\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\Administrator.DAI-PC2\anaconda3\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 454/454 - 6s - loss: 0.7902 - accuracy: 0.7306 - val_loss: 0.4989 - val_accuracy: 0.8565 - 6s/epoch - 14ms/step
# Epoch 2/101
# 454/454 - 2s - loss: 0.4828 - accuracy: 0.8495 - val_loss: 0.4004 - val_accuracy: 0.8667 - 2s/epoch - 5ms/step
# Epoch 3/101
# 454/454 - 2s - loss: 0.4226 - accuracy: 0.8579 - val_loss: 0.3771 - val_accuracy: 0.8705 - 2s/epoch - 5ms/step
# Epoch 4/101
# 454/454 - 2s - loss: 0.3953 - accuracy: 0.8629 - val_loss: 0.3623 - val_accuracy: 0.8736 - 2s/epoch - 5ms/step
# Epoch 5/101
# 454/454 - 2s - loss: 0.3806 - accuracy: 0.8649 - val_loss: 0.3546 - val_accuracy: 0.8713 - 2s/epoch - 5ms/step
# Epoch 6/101
# 454/454 - 2s - loss: 0.3760 - accuracy: 0.8663 - val_loss: 0.3426 - val_accuracy: 0.8760 - 2s/epoch - 5ms/step
# Epoch 7/101
# 454/454 - 2s - loss: 0.3622 - accuracy: 0.8675 - val_loss: 0.3415 - val_accuracy: 0.8747 - 2s/epoch - 4ms/step
# Epoch 8/101
# 454/454 - 2s - loss: 0.3563 - accuracy: 0.8688 - val_loss: 0.3350 - val_accuracy: 0.8791 - 2s/epoch - 5ms/step
# Epoch 9/101
# 454/454 - 2s - loss: 0.3530 - accuracy: 0.8695 - val_loss: 0.3376 - val_accuracy: 0.8716 - 2s/epoch - 5ms/step
# Epoch 10/101
# 454/454 - 2s - loss: 0.3468 - accuracy: 0.8736 - val_loss: 0.3343 - val_accuracy: 0.8760 - 2s/epoch - 5ms/step
# Epoch 11/101
# 454/454 - 2s - loss: 0.3519 - accuracy: 0.8681 - val_loss: 0.3274 - val_accuracy: 0.8791 - 2s/epoch - 5ms/step
# Epoch 12/101
# 454/454 - 2s - loss: 0.3392 - accuracy: 0.8757 - val_loss: 0.3266 - val_accuracy: 0.8782 - 2s/epoch - 5ms/step
# Epoch 13/101
# 454/454 - 2s - loss: 0.3412 - accuracy: 0.8730 - val_loss: 0.3251 - val_accuracy: 0.8766 - 2s/epoch - 5ms/step
# Epoch 14/101
# 454/454 - 2s - loss: 0.3381 - accuracy: 0.8713 - val_loss: 0.3222 - val_accuracy: 0.8804 - 2s/epoch - 5ms/step
# Epoch 15/101
# 454/454 - 2s - loss: 0.3294 - accuracy: 0.8774 - val_loss: 0.3258 - val_accuracy: 0.8747 - 2s/epoch - 5ms/step
# Epoch 16/101
# 454/454 - 2s - loss: 0.3281 - accuracy: 0.8747 - val_loss: 0.3191 - val_accuracy: 0.8804 - 2s/epoch - 5ms/step
# Epoch 17/101
# 454/454 - 2s - loss: 0.3305 - accuracy: 0.8721 - val_loss: 0.3263 - val_accuracy: 0.8741 - 2s/epoch - 5ms/step
# Epoch 18/101
# 454/454 - 2s - loss: 0.3289 - accuracy: 0.8767 - val_loss: 0.3202 - val_accuracy: 0.8780 - 2s/epoch - 5ms/step
# Epoch 19/101
# 454/454 - 2s - loss: 0.3250 - accuracy: 0.8765 - val_loss: 0.3231 - val_accuracy: 0.8796 - 2s/epoch - 5ms/step
# Epoch 20/101
# 454/454 - 2s - loss: 0.3240 - accuracy: 0.8757 - val_loss: 0.3280 - val_accuracy: 0.8711 - 2s/epoch - 5ms/step
# Epoch 21/101
# 454/454 - 2s - loss: 0.3229 - accuracy: 0.8761 - val_loss: 0.3182 - val_accuracy: 0.8758 - 2s/epoch - 5ms/step
# Epoch 22/101
# 454/454 - 2s - loss: 0.3239 - accuracy: 0.8763 - val_loss: 0.3230 - val_accuracy: 0.8730 - 2s/epoch - 5ms/step
# Epoch 23/101
# 454/454 - 2s - loss: 0.3221 - accuracy: 0.8775 - val_loss: 0.3164 - val_accuracy: 0.8807 - 2s/epoch - 5ms/step
# Epoch 24/101
# 454/454 - 3s - loss: 0.3217 - accuracy: 0.8776 - val_loss: 0.3187 - val_accuracy: 0.8752 - 3s/epoch - 6ms/step
# Epoch 25/101
# 454/454 - 2s - loss: 0.3184 - accuracy: 0.8776 - val_loss: 0.3130 - val_accuracy: 0.8815 - 2s/epoch - 5ms/step
# Epoch 26/101
# 454/454 - 2s - loss: 0.3138 - accuracy: 0.8786 - val_loss: 0.3219 - val_accuracy: 0.8744 - 2s/epoch - 5ms/step
# Epoch 27/101
# 454/454 - 2s - loss: 0.3184 - accuracy: 0.8769 - val_loss: 0.3208 - val_accuracy: 0.8744 - 2s/epoch - 5ms/step
# Epoch 28/101
# 454/454 - 2s - loss: 0.3174 - accuracy: 0.8798 - val_loss: 0.3189 - val_accuracy: 0.8755 - 2s/epoch - 5ms/step
# Epoch 29/101
# 454/454 - 2s - loss: 0.3223 - accuracy: 0.8749 - val_loss: 0.3219 - val_accuracy: 0.8741 - 2s/epoch - 4ms/step
# Epoch 30/101
# 454/454 - 2s - loss: 0.3125 - accuracy: 0.8827 - val_loss: 0.3216 - val_accuracy: 0.8725 - 2s/epoch - 5ms/step
# Epoch 31/101
# 454/454 - 2s - loss: 0.3136 - accuracy: 0.8779 - val_loss: 0.3191 - val_accuracy: 0.8744 - 2s/epoch - 5ms/step
# Epoch 32/101
# 454/454 - 2s - loss: 0.3091 - accuracy: 0.8800 - val_loss: 0.3217 - val_accuracy: 0.8738 - 2s/epoch - 5ms/step
# Epoch 33/101
# 454/454 - 2s - loss: 0.3137 - accuracy: 0.8789 - val_loss: 0.3261 - val_accuracy: 0.8708 - 2s/epoch - 5ms/step
# Epoch 34/101
# 454/454 - 2s - loss: 0.3084 - accuracy: 0.8808 - val_loss: 0.3185 - val_accuracy: 0.8744 - 2s/epoch - 5ms/step
# Epoch 35/101
# 454/454 - 2s - loss: 0.3114 - accuracy: 0.8792 - val_loss: 0.3161 - val_accuracy: 0.8741 - 2s/epoch - 5ms/step
# Epoch 36/101
# 454/454 - 2s - loss: 0.3087 - accuracy: 0.8797 - val_loss: 0.3177 - val_accuracy: 0.8741 - 2s/epoch - 4ms/step
# Epoch 37/101
# 454/454 - 2s - loss: 0.3064 - accuracy: 0.8810 - val_loss: 0.3168 - val_accuracy: 0.8771 - 2s/epoch - 5ms/step
# Epoch 38/101
# 454/454 - 3s - loss: 0.3058 - accuracy: 0.8818 - val_loss: 0.3148 - val_accuracy: 0.8793 - 3s/epoch - 6ms/step
# Epoch 39/101
# 454/454 - 2s - loss: 0.3107 - accuracy: 0.8795 - val_loss: 0.3237 - val_accuracy: 0.8711 - 2s/epoch - 5ms/step
# Epoch 40/101
# 454/454 - 2s - loss: 0.3069 - accuracy: 0.8807 - val_loss: 0.3277 - val_accuracy: 0.8725 - 2s/epoch - 5ms/step
# Epoch 41/101
# 454/454 - 2s - loss: 0.3121 - accuracy: 0.8786 - val_loss: 0.3207 - val_accuracy: 0.8760 - 2s/epoch - 5ms/step
# Epoch 42/101
# 454/454 - 2s - loss: 0.3054 - accuracy: 0.8792 - val_loss: 0.3222 - val_accuracy: 0.8755 - 2s/epoch - 4ms/step
# Epoch 43/101
# 454/454 - 2s - loss: 0.3099 - accuracy: 0.8801 - val_loss: 0.3230 - val_accuracy: 0.8689 - 2s/epoch - 4ms/step
# Epoch 44/101
# 454/454 - 2s - loss: 0.3034 - accuracy: 0.8847 - val_loss: 0.3182 - val_accuracy: 0.8771 - 2s/epoch - 5ms/step
# Epoch 45/101
# 454/454 - 2s - loss: 0.3034 - accuracy: 0.8825 - val_loss: 0.3246 - val_accuracy: 0.8813 - 2s/epoch - 5ms/step
# Epoch 46/101
# 454/454 - 2s - loss: 0.3040 - accuracy: 0.8810 - val_loss: 0.3204 - val_accuracy: 0.8741 - 2s/epoch - 5ms/step
# Epoch 47/101
# 454/454 - 2s - loss: 0.3072 - accuracy: 0.8815 - val_loss: 0.3227 - val_accuracy: 0.8713 - 2s/epoch - 5ms/step
# Epoch 48/101
# 454/454 - 2s - loss: 0.3048 - accuracy: 0.8813 - val_loss: 0.3176 - val_accuracy: 0.8755 - 2s/epoch - 5ms/step
# Epoch 49/101
# 454/454 - 2s - loss: 0.3082 - accuracy: 0.8820 - val_loss: 0.3182 - val_accuracy: 0.8733 - 2s/epoch - 5ms/step
# Epoch 50/101
# 454/454 - 2s - loss: 0.3076 - accuracy: 0.8809 - val_loss: 0.3198 - val_accuracy: 0.8725 - 2s/epoch - 4ms/step
# Epoch 51/101
# 454/454 - 2s - loss: 0.3025 - accuracy: 0.8827 - val_loss: 0.3210 - val_accuracy: 0.8719 - 2s/epoch - 5ms/step
# Epoch 52/101
# 454/454 - 2s - loss: 0.3025 - accuracy: 0.8834 - val_loss: 0.3186 - val_accuracy: 0.8744 - 2s/epoch - 4ms/step
# Epoch 53/101
# 454/454 - 2s - loss: 0.3033 - accuracy: 0.8842 - val_loss: 0.3214 - val_accuracy: 0.8763 - 2s/epoch - 4ms/step
# Epoch 54/101
# 454/454 - 2s - loss: 0.3017 - accuracy: 0.8844 - val_loss: 0.3161 - val_accuracy: 0.8774 - 2s/epoch - 5ms/step
# Epoch 55/101
# 454/454 - 2s - loss: 0.3022 - accuracy: 0.8830 - val_loss: 0.3299 - val_accuracy: 0.8686 - 2s/epoch - 5ms/step
# Epoch 56/101
# 454/454 - 2s - loss: 0.3032 - accuracy: 0.8808 - val_loss: 0.3184 - val_accuracy: 0.8738 - 2s/epoch - 5ms/step
# Epoch 57/101
# 454/454 - 2s - loss: 0.2997 - accuracy: 0.8849 - val_loss: 0.3275 - val_accuracy: 0.8713 - 2s/epoch - 4ms/step
# Epoch 58/101
# 454/454 - 2s - loss: 0.2973 - accuracy: 0.8852 - val_loss: 0.3245 - val_accuracy: 0.8705 - 2s/epoch - 5ms/step
# Epoch 59/101
# 454/454 - 2s - loss: 0.3018 - accuracy: 0.8830 - val_loss: 0.3253 - val_accuracy: 0.8744 - 2s/epoch - 5ms/step
# Epoch 60/101
# 454/454 - 2s - loss: 0.3009 - accuracy: 0.8828 - val_loss: 0.3180 - val_accuracy: 0.8769 - 2s/epoch - 5ms/step
# Epoch 61/101
# 454/454 - 2s - loss: 0.3000 - accuracy: 0.8830 - val_loss: 0.3191 - val_accuracy: 0.8738 - 2s/epoch - 5ms/step
# Epoch 62/101
# 454/454 - 2s - loss: 0.3036 - accuracy: 0.8811 - val_loss: 0.3212 - val_accuracy: 0.8738 - 2s/epoch - 5ms/step
# Epoch 63/101
# 454/454 - 2s - loss: 0.2991 - accuracy: 0.8830 - val_loss: 0.3267 - val_accuracy: 0.8719 - 2s/epoch - 4ms/step
# Epoch 64/101
# 454/454 - 2s - loss: 0.3014 - accuracy: 0.8823 - val_loss: 0.3177 - val_accuracy: 0.8766 - 2s/epoch - 5ms/step
# Epoch 65/101
# 454/454 - 2s - loss: 0.2989 - accuracy: 0.8816 - val_loss: 0.3274 - val_accuracy: 0.8713 - 2s/epoch - 5ms/step
# Epoch 66/101
# 454/454 - 2s - loss: 0.3016 - accuracy: 0.8837 - val_loss: 0.3187 - val_accuracy: 0.8799 - 2s/epoch - 5ms/step
# Epoch 67/101
# 454/454 - 2s - loss: 0.2979 - accuracy: 0.8855 - val_loss: 0.3235 - val_accuracy: 0.8736 - 2s/epoch - 5ms/step
# Epoch 68/101
# 454/454 - 2s - loss: 0.3000 - accuracy: 0.8805 - val_loss: 0.3185 - val_accuracy: 0.8755 - 2s/epoch - 5ms/step
# Epoch 69/101
# 454/454 - 2s - loss: 0.3050 - accuracy: 0.8821 - val_loss: 0.3222 - val_accuracy: 0.8741 - 2s/epoch - 5ms/step
# Epoch 70/101
# 454/454 - 2s - loss: 0.3011 - accuracy: 0.8825 - val_loss: 0.3198 - val_accuracy: 0.8733 - 2s/epoch - 5ms/step
# Epoch 71/101
# 454/454 - 2s - loss: 0.3026 - accuracy: 0.8823 - val_loss: 0.3173 - val_accuracy: 0.8766 - 2s/epoch - 5ms/step
# Epoch 72/101
# 454/454 - 2s - loss: 0.3000 - accuracy: 0.8832 - val_loss: 0.3263 - val_accuracy: 0.8700 - 2s/epoch - 4ms/step
# Epoch 73/101
# 454/454 - 2s - loss: 0.2975 - accuracy: 0.8815 - val_loss: 0.3237 - val_accuracy: 0.8741 - 2s/epoch - 5ms/step
# Epoch 74/101
# 454/454 - 2s - loss: 0.2961 - accuracy: 0.8854 - val_loss: 0.3218 - val_accuracy: 0.8747 - 2s/epoch - 5ms/step
# Epoch 75/101
# 454/454 - 2s - loss: 0.3005 - accuracy: 0.8843 - val_loss: 0.3286 - val_accuracy: 0.8658 - 2s/epoch - 5ms/step
# Epoch 76/101
# 454/454 - 2s - loss: 0.3021 - accuracy: 0.8823 - val_loss: 0.3361 - val_accuracy: 0.8661 - 2s/epoch - 5ms/step
# Epoch 77/101
# 454/454 - 2s - loss: 0.2977 - accuracy: 0.8841 - val_loss: 0.3221 - val_accuracy: 0.8771 - 2s/epoch - 5ms/step
# Epoch 78/101
# 454/454 - 2s - loss: 0.3056 - accuracy: 0.8798 - val_loss: 0.3272 - val_accuracy: 0.8725 - 2s/epoch - 5ms/step
# Epoch 79/101
# 454/454 - 2s - loss: 0.2961 - accuracy: 0.8848 - val_loss: 0.3302 - val_accuracy: 0.8711 - 2s/epoch - 5ms/step
# Epoch 80/101
# 454/454 - 2s - loss: 0.2990 - accuracy: 0.8846 - val_loss: 0.3267 - val_accuracy: 0.8691 - 2s/epoch - 5ms/step
# Epoch 81/101
# 454/454 - 2s - loss: 0.2991 - accuracy: 0.8838 - val_loss: 0.3247 - val_accuracy: 0.8763 - 2s/epoch - 5ms/step
# Epoch 82/101
# 454/454 - 2s - loss: 0.2994 - accuracy: 0.8839 - val_loss: 0.3336 - val_accuracy: 0.8705 - 2s/epoch - 5ms/step
# Epoch 83/101
# 454/454 - 2s - loss: 0.3005 - accuracy: 0.8815 - val_loss: 0.3284 - val_accuracy: 0.8694 - 2s/epoch - 5ms/step
# Epoch 84/101
# 454/454 - 2s - loss: 0.2959 - accuracy: 0.8876 - val_loss: 0.3382 - val_accuracy: 0.8683 - 2s/epoch - 5ms/step
# Epoch 85/101
# 454/454 - 2s - loss: 0.2957 - accuracy: 0.8856 - val_loss: 0.3306 - val_accuracy: 0.8689 - 2s/epoch - 5ms/step
# Epoch 86/101
# 454/454 - 2s - loss: 0.2976 - accuracy: 0.8838 - val_loss: 0.3223 - val_accuracy: 0.8708 - 2s/epoch - 4ms/step
# Epoch 87/101
# 454/454 - 2s - loss: 0.2928 - accuracy: 0.8879 - val_loss: 0.3297 - val_accuracy: 0.8689 - 2s/epoch - 5ms/step
# Epoch 88/101
# 454/454 - 2s - loss: 0.2986 - accuracy: 0.8839 - val_loss: 0.3255 - val_accuracy: 0.8716 - 2s/epoch - 5ms/step
# Epoch 89/101
# 454/454 - 2s - loss: 0.2975 - accuracy: 0.8849 - val_loss: 0.3279 - val_accuracy: 0.8755 - 2s/epoch - 5ms/step
# Epoch 90/101
# 454/454 - 2s - loss: 0.2961 - accuracy: 0.8861 - val_loss: 0.3354 - val_accuracy: 0.8683 - 2s/epoch - 5ms/step
# Epoch 91/101
# 454/454 - 2s - loss: 0.2978 - accuracy: 0.8825 - val_loss: 0.3198 - val_accuracy: 0.8763 - 2s/epoch - 5ms/step
# Epoch 92/101
# 454/454 - 2s - loss: 0.2952 - accuracy: 0.8854 - val_loss: 0.3269 - val_accuracy: 0.8749 - 2s/epoch - 5ms/step
# Epoch 93/101
# 454/454 - 2s - loss: 0.2995 - accuracy: 0.8831 - val_loss: 0.3231 - val_accuracy: 0.8744 - 2s/epoch - 5ms/step
# Epoch 94/101
# 454/454 - 2s - loss: 0.2925 - accuracy: 0.8879 - val_loss: 0.3245 - val_accuracy: 0.8725 - 2s/epoch - 5ms/step
# Epoch 95/101
# 454/454 - 2s - loss: 0.2948 - accuracy: 0.8864 - val_loss: 0.3263 - val_accuracy: 0.8747 - 2s/epoch - 5ms/step
# Epoch 96/101
# 454/454 - 2s - loss: 0.2920 - accuracy: 0.8861 - val_loss: 0.3207 - val_accuracy: 0.8749 - 2s/epoch - 5ms/step
# Epoch 97/101
# 454/454 - 2s - loss: 0.2990 - accuracy: 0.8854 - val_loss: 0.3296 - val_accuracy: 0.8780 - 2s/epoch - 5ms/step
# Epoch 98/101
# 454/454 - 2s - loss: 0.2942 - accuracy: 0.8860 - val_loss: 0.3194 - val_accuracy: 0.8758 - 2s/epoch - 5ms/step
# Epoch 99/101
# 454/454 - 2s - loss: 0.2936 - accuracy: 0.8861 - val_loss: 0.3305 - val_accuracy: 0.8741 - 2s/epoch - 5ms/step
# Epoch 100/101
# 454/454 - 2s - loss: 0.2931 - accuracy: 0.8901 - val_loss: 0.3389 - val_accuracy: 0.8736 - 2s/epoch - 5ms/step
# Epoch 101/101
# 454/454 - 2s - loss: 0.2936 - accuracy: 0.8855 - val_loss: 0.3330 - val_accuracy: 0.8708 - 2s/epoch - 4ms/step

# %%
fn_plot_tf_hist(pd.DataFrame(history.history))

# %%
loss_df = pd.DataFrame(history.history)
loss_df[loss_df['val_loss'] == loss_df['val_loss'].min()]
# Out:
#         loss  accuracy  val_loss  val_accuracy
# 24  0.318383  0.877592  0.312972      0.881543
